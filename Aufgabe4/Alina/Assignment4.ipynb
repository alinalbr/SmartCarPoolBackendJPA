# %% [markdown]
# <a href="https://colab.research.google.com/github/alinalbr/SmartCarPoolBackendJPA/blob/master/Aufgabe4/Alina/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import torch

# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/KI_Lab/train.csv', error_bad_lines=False, sep=';', names=['labels','text'])

# %%
print(df)
# Out:
#              labels                                               text
# 0             Sport  21-Jähriger fällt wohl bis Saisonende aus. Wie...
# 1            Kultur  'Erfundene Bilder zu Filmen, die als verloren ...
# 2               Web  Der frischgekürte CEO Sundar Pichai setzt auf ...
# 3        Wirtschaft  Putin: "Einigung, dass wir Menge auf Niveau vo...
# 4            Inland  Estland sieht den künftigen österreichischen P...
# ...             ...                                                ...
# 9240         Inland  Bernd Saurer war Bridge-Juniorenweltmeister un...
# 9241  International  Sandhere soll in vergangener Woche bei Luftang...
# 9242     Wirtschaft  Derzeit Konzeptgruppe in Berlin – Kein Komment...
# 9243         Inland  Landeshauptmann will den vierten Regierungssit...
# 9244       Panorama  Er ist einer von Millionen syrischen Flüchtlin...
#
# [9245 rows x 2 columns]

# %%
#From github
#url = 'https://raw.githubusercontent.com/tblock/10kGNAD/master/train.csv'
#df = pd.read_csv(url, error_bad_lines=False)

# %%
df = df.drop('labels', axis = 1)
df
# Out:
#                                                    text
# 0     21-Jähriger fällt wohl bis Saisonende aus. Wie...
# 1     'Erfundene Bilder zu Filmen, die als verloren ...
# 2     Der frischgekürte CEO Sundar Pichai setzt auf ...
# 3     Putin: "Einigung, dass wir Menge auf Niveau vo...
# 4     Estland sieht den künftigen österreichischen P...
# ...                                                 ...
# 9240  Bernd Saurer war Bridge-Juniorenweltmeister un...
# 9241  Sandhere soll in vergangener Woche bei Luftang...
# 9242  Derzeit Konzeptgruppe in Berlin – Kein Komment...
# 9243  Landeshauptmann will den vierten Regierungssit...
# 9244  Er ist einer von Millionen syrischen Flüchtlin...
#
# [9245 rows x 1 columns]

# %% [markdown]
# Install spacy

# %%
# !pip install -U spacy[cuda100] de
# Out:
# Collecting spacy[cuda100]
#   Downloading https://files.pythonhosted.org/packages/10/b5/c7a92c7ce5d4b353b70b4b5b4385687206c8b230ddfe08746ab0fd310a3a/spacy-2.3.2-cp36-cp36m-manylinux1_x86_64.whl (9.9MB)
#      |████████████████████████████████| 10.0MB 7.4MB/s
# Collecting de
#   Downloading https://files.pythonhosted.org/packages/d7/b8/ee2e5c22775450d2a8751273a4b3cfa6e47cdb6393dd803b6317a85d213c/de-0.1.tar.gz
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy[cuda100]) (50.3.2)
# Requirement already satisfied, skipping upgrade: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy[cuda100]) (0.4.1)
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy[cuda100]) (3.0.2)
# Collecting thinc==7.4.1
#   Downloading https://files.pythonhosted.org/packages/10/ae/ef3ae5e93639c0ef8e3eb32e3c18341e511b3c515fcfc603f4b808087651/thinc-7.4.1-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 52.7MB/s
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy[cuda100]) (1.0.3)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy[cuda100]) (4.41.1)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy[cuda100]) (0.8.0)
# Requirement already satisfied, skipping upgrade: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy[cuda100]) (1.0.0)
# Requirement already satisfied, skipping upgrade: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy[cuda100]) (1.0.2)
# Requirement already satisfied, skipping upgrade: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy[cuda100]) (2.23.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy[cuda100]) (1.18.5)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy[cuda100]) (2.0.4)
# Requirement already satisfied, skipping upgrade: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy[cuda100]) (1.1.3)
# Collecting cupy-cuda100<9.0.0,>=5.0.0b4; extra == "cuda100"
#   Downloading https://files.pythonhosted.org/packages/bd/f5/a2d40c30346aa1b8e0321db054cac8e4f10e28bf35a6da4d1481d2bfded9/cupy_cuda100-8.1.0-cp36-cp36m-manylinux1_x86_64.whl (370.3MB)
#      |████████████████████████████████| 370.3MB 44kB/s
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy[cuda100]) (2.0.0)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy[cuda100]) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy[cuda100]) (2020.6.20)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy[cuda100]) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy[cuda100]) (3.0.4)
# Requirement already satisfied, skipping upgrade: fastrlock>=0.3 in /usr/local/lib/python3.6/dist-packages (from cupy-cuda100<9.0.0,>=5.0.0b4; extra == "cuda100"->spacy[cuda100]) (0.5)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy[cuda100]) (3.4.0)
# Building wheels for collected packages: de
#   Building wheel for de (setup.py) ... done
#   Created wheel for de: filename=de-0.1-cp36-none-any.whl size=1158 sha256=361470df62f761c8e12c9fd0c0b156dd88587c1f29f01ae2e18d81aa458dd8d7
#   Stored in directory: /root/.cache/pip/wheels/fd/16/b9/46fac6c03128929538323f5457e947af752b7c58d4c7783f04
# Successfully built de
# Installing collected packages: thinc, cupy-cuda100, spacy, de
#   Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# Successfully installed cupy-cuda100-8.1.0 de-0.1 spacy-2.3.2 thinc-7.4.1

# %% [markdown]
# 4. Use spaCy to get all nouns in the whole file.

# %%
# !python -m spacy download de
import spacy
# Out:
# Collecting de_core_news_sm==2.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-2.3.0/de_core_news_sm-2.3.0.tar.gz (14.9MB)
#      |████████████████████████████████| 14.9MB 724kB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from de_core_news_sm==2.3.0) (2.3.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (1.0.3)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (1.1.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (4.41.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (3.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (0.8.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (2.0.4)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (50.3.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (1.18.5)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (7.4.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (2.10)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->de_core_news_sm==2.3.0) (3.4.0)
# Building wheels for collected packages: de-core-news-sm
#   Building wheel for de-core-news-sm (setup.py) ... done
#   Created wheel for de-core-news-sm: filename=de_core_news_sm-2.3.0-cp36-none-any.whl size=14907580 sha256=4764a65513c3d6d995b319f4051ed7f7a8051e3e20c28a54dcc898ec6445650c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7tk1y_0u/wheels/db/f3/1e/0df0f27eee12bd1aaa94bcfef11b01eca62f90b9b9a0ce08fd
# Successfully built de-core-news-sm
# Installing collected packages: de-core-news-sm
# Successfully installed de-core-news-sm-2.3.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('de_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/de_core_news_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/de
# You can now load the model via spacy.load('de')

# %%
gpu = spacy.prefer_gpu()
print('GPU:', gpu)
# Out:
# GPU: True

# %%
nlp = spacy.load("de")

# %%
list_nouns =[]
df = df[0:200]
for index, row in df.iterrows():
  doc = nlp(row['text'])
  for token in doc:
    if token.pos_ == 'NOUN': 
      list_nouns.append(token.text)

# %%
print(list_nouns)
# Out:
# ['21-Jähriger', 'Saisonende', 'Saisonende', 'Offensivspieler', 'Winter', 'Ried', '21-Jährige', '0:4-Heimdebakel', 'Samstag', 'Teilriss', 'Innenbandes', 'Knie', 'Magnetresonanz-Untersuchung', 'Donnerstag', 'Schiene', 'Pause', 'Bilder', 'Filmen', 'Ritt', 'Labyrinthe', 'Kinos', 'Filmgeschichte', 'Friedhof', 'Verlorenen', 'Begrabenen', 'Filme', 'Namen', 'Führungsteam', 'Atmosphäre', 'Mitarbeiter', 'Konkurrenz', 'Löhne', 'Mauscheleien', 'Untergebene', 'Ziele', 'Tür', 'Firmenebene', 'Umgangsformen', 'Wutausbrüche', 'Apple-Mitgründer', 'Geschäftspartner', 'Lebzeiten', 'Arschloch', 'Google-Mitgründer', 'Choleriker', 'Umgang', 'Mitarbeitern', 'Stelle', 'Zeiten', 'Management-Stils', 'Mitarbeiter', 'Geschäftspartner', 'Ex-Manager', 'Arschlöcher', 'Umstrukturierung', 'Gründung', 'Dachunternehmens', 'Suchmaschinisten', 'Monaten', 'Google-Chef', 'Umstrukturierungen', 'Lob', 'Branche', 'Android-Chef', 'Kollegen', 'Motorola-Präsident', 'Typen', 'Smartphone-Hersteller', 'Android', 'Zugang', 'Entwicklungen', 'Betriebssystems', 'Beispiel', 'Werbegeschäft', 'Medienpartner', 'kompromissbereit', 'Monopol-Vorwürfe', 'Regierungskreisen', 'Semester', 'Google-Umfeld', 'Google', 'Scharmützel', 'Zeit', 'Ellbogen', 'Putin', 'Einigung', 'Menge', 'Niveau', 'Jänner', 'Ölproduzenten', 'Worten', 'Präsident', 'Förderung', 'Jahr', 'Großen', 'Ganzen', 'Einigung', 'Ölproduktion', 'Niveau', 'Jänner', 'Mittwoch', 'Förderstaaten', 'Einbruch', 'Ölpreise', 'Putin', 'Preise', 'Förderung', 'Ausland', 'Förderländern', 'Einfrieren', 'Produktion', 'Präsidenten', 'Staatsbürger', 'Tallinn', 'Eltern', 'Bundespräsidenten', 'Sowjets', 'Estland', 'Reich', 'Bellen', 'Welt', 'Verwandte', 'Dienstag', 'Wahlsieg', 'Freude', 'Politikern', 'Landes', 'Interesse', 'Bellen', 'Stadt', 'Geburtsstadt', 'Eltern', 'Herzen', 'Familie', 'Cousine', 'Präsidenten', 'Sonntag', 'Stress', 'Telefonat', 'Sieg', 'Intelligenzija', 'Menschen', 'Philologin', 'Dorf', 'Süden', 'Wahlsieg', 'Grünen-Chefs', 'Politikern', 'Wahl', 'Präsidenten', 'Wurzeln', 'Bedingungen', 'Zusammenarbeit', 'Vorsitzende', 'Ausschusses', 'Parlament', 'Aufschwung', 'Kräfte', 'Sorge', 'Österreicher', 'Bellen', 'Vertreter', 'Partei', 'Wahlergebnis', 'Grund', 'Österreichern', 'Außenminister', 'Europaparlamentsabgeordnete', 'Bellen', 'Zeit', 'Wahl', 'Gespräch', 'Volk', 'Tatsache', 'Rolle', 'Staatsbürger', 'Präsidenten', 'Auskunft', 'Außenministeriums', 'Kinder', 'Bewohnern', 'Estland', 'Juni', 'Staatsbürgerschaft', 'Staatsbürger', 'Estland', 'Dokumente', 'Staatsarchivs', 'Bundesarchivs', 'Bellen', 'Eltern', 'Präsidenten', 'Besitz', 'Staatsbürgerschaft', 'Interesse', 'Präsidenten', 'Westen', 'Grenze', 'Familie', 'Jahrhundert', 'Adelstand', 'Großvater', 'Bellen', 'Oktoberrevolution', 'Jahres', 'Funktion', 'Region', 'Februarrevolution', 'Vertreter', 'Liberalismus', 'Kommissar', 'Übergangsregierung', 'Gouvernement', 'Regierungschef', 'Lokalmedien', 'Schlagzeilen', 'Sieg', 'Nachfahren', 'Aristokraten', 'Enkels', 'Pskower', 'Rede', 'Direktor', 'Archivs', 'Region', 'Archiv', 'Akten', 'Familie', 'Bellen', 'Tätigkeit', 'Vorfahren', 'Gespräch', 'Zeit', 'Publikationen', 'Van', 'Bellens', 'Geschichte', 'Kleinaristokraten', 'Machtübernahme', 'Bolschewiken', 'Ende', 'Familie', 'Großeltern', 'Vater', 'Präsidenten', 'Sowjets', 'Estland', 'Richtung', 'Westen', 'Vater', 'Zeitpunkt', 'Herkunft', 'Repressionen', 'Geheimdiensts', 'Flucht', 'Ende', 'Anfang', 'Eintreffen', 'Armee', 'Bellen', 'Existenz', 'Außenhandel', 'Präsident', 'Welser', 'Zukäufe', 'Trodat', 'GmbH', 'Sitz', 'US-Unternehmen', 'Laserbereich', 'Experten', 'Kunststoffe', 'Stempelhersteller', 'Stellung', 'Weltmarktführer', 'Stempel', 'Pressemitteilung', 'Unternehmens', 'Dienstag', 'Gruppe', 'Umsatz', 'Mio.', 'Euro', 'Mio.', 'Jahr', 'Mio.', 'Umsatzsteigerung', 'Mio.', 'Euro', 'Wachstum', 'Übernahmen', 'Mitarbeitern', 'Mio.', 'US-Dollar', 'Mio.', 'Euro', 'Standort', 'Leuten', 'Mio.', 'US-Dollar', 'Mio.', 'Euro', 'Übernahme', 'Marktstellung', 'Trodat', 'Geschäftsführer', 'Trodat-Stempelumsatz', 'Mio. ...

# %%
import string
all_letters = string.ascii_letters + "ÄÖÜäöüß"
list_nouns_ascii = []

for noun in list_nouns:
  contained = True
  
  for char in noun:
    if char not in all_letters:
      contained = False
      break

  if contained:
    list_nouns_ascii.append(noun)

print(list_nouns_ascii)
# Out:
# ['Saisonende', 'Saisonende', 'Offensivspieler', 'Winter', 'Ried', 'Samstag', 'Teilriss', 'Innenbandes', 'Knie', 'Donnerstag', 'Schiene', 'Pause', 'Bilder', 'Filmen', 'Ritt', 'Labyrinthe', 'Kinos', 'Filmgeschichte', 'Friedhof', 'Verlorenen', 'Begrabenen', 'Filme', 'Namen', 'Führungsteam', 'Atmosphäre', 'Mitarbeiter', 'Konkurrenz', 'Löhne', 'Mauscheleien', 'Untergebene', 'Ziele', 'Tür', 'Firmenebene', 'Umgangsformen', 'Wutausbrüche', 'Geschäftspartner', 'Lebzeiten', 'Arschloch', 'Choleriker', 'Umgang', 'Mitarbeitern', 'Stelle', 'Zeiten', 'Mitarbeiter', 'Geschäftspartner', 'Arschlöcher', 'Umstrukturierung', 'Gründung', 'Dachunternehmens', 'Suchmaschinisten', 'Monaten', 'Umstrukturierungen', 'Lob', 'Branche', 'Kollegen', 'Typen', 'Android', 'Zugang', 'Entwicklungen', 'Betriebssystems', 'Beispiel', 'Werbegeschäft', 'Medienpartner', 'kompromissbereit', 'Regierungskreisen', 'Semester', 'Google', 'Scharmützel', 'Zeit', 'Ellbogen', 'Putin', 'Einigung', 'Menge', 'Niveau', 'Jänner', 'Ölproduzenten', 'Worten', 'Präsident', 'Förderung', 'Jahr', 'Großen', 'Ganzen', 'Einigung', 'Ölproduktion', 'Niveau', 'Jänner', 'Mittwoch', 'Förderstaaten', 'Einbruch', 'Ölpreise', 'Putin', 'Preise', 'Förderung', 'Ausland', 'Förderländern', 'Einfrieren', 'Produktion', 'Präsidenten', 'Staatsbürger', 'Tallinn', 'Eltern', 'Bundespräsidenten', 'Sowjets', 'Estland', 'Reich', 'Bellen', 'Welt', 'Verwandte', 'Dienstag', 'Wahlsieg', 'Freude', 'Politikern', 'Landes', 'Interesse', 'Bellen', 'Stadt', 'Geburtsstadt', 'Eltern', 'Herzen', 'Familie', 'Cousine', 'Präsidenten', 'Sonntag', 'Stress', 'Telefonat', 'Sieg', 'Intelligenzija', 'Menschen', 'Philologin', 'Dorf', 'Süden', 'Wahlsieg', 'Politikern', 'Wahl', 'Präsidenten', 'Wurzeln', 'Bedingungen', 'Zusammenarbeit', 'Vorsitzende', 'Ausschusses', 'Parlament', 'Aufschwung', 'Kräfte', 'Sorge', 'Österreicher', 'Bellen', 'Vertreter', 'Partei', 'Wahlergebnis', 'Grund', 'Österreichern', 'Außenminister', 'Europaparlamentsabgeordnete', 'Bellen', 'Zeit', 'Wahl', 'Gespräch', 'Volk', 'Tatsache', 'Rolle', 'Staatsbürger', 'Präsidenten', 'Auskunft', 'Außenministeriums', 'Kinder', 'Bewohnern', 'Estland', 'Juni', 'Staatsbürgerschaft', 'Staatsbürger', 'Estland', 'Dokumente', 'Staatsarchivs', 'Bundesarchivs', 'Bellen', 'Eltern', 'Präsidenten', 'Besitz', 'Staatsbürgerschaft', 'Interesse', 'Präsidenten', 'Westen', 'Grenze', 'Familie', 'Jahrhundert', 'Adelstand', 'Großvater', 'Bellen', 'Oktoberrevolution', 'Jahres', 'Funktion', 'Region', 'Februarrevolution', 'Vertreter', 'Liberalismus', 'Kommissar', 'Übergangsregierung', 'Gouvernement', 'Regierungschef', 'Lokalmedien', 'Schlagzeilen', 'Sieg', 'Nachfahren', 'Aristokraten', 'Enkels', 'Pskower', 'Rede', 'Direktor', 'Archivs', 'Region', 'Archiv', 'Akten', 'Familie', 'Bellen', 'Tätigkeit', 'Vorfahren', 'Gespräch', 'Zeit', 'Publikationen', 'Van', 'Bellens', 'Geschichte', 'Kleinaristokraten', 'Machtübernahme', 'Bolschewiken', 'Ende', 'Familie', 'Großeltern', 'Vater', 'Präsidenten', 'Sowjets', 'Estland', 'Richtung', 'Westen', 'Vater', 'Zeitpunkt', 'Herkunft', 'Repressionen', 'Geheimdiensts', 'Flucht', 'Ende', 'Anfang', 'Eintreffen', 'Armee', 'Bellen', 'Existenz', 'Außenhandel', 'Präsident', 'Welser', 'Zukäufe', 'Trodat', 'GmbH', 'Sitz', 'Laserbereich', 'Experten', 'Kunststoffe', 'Stempelhersteller', 'Stellung', 'Weltmarktführer', 'Stempel', 'Pressemitteilung', 'Unternehmens', 'Dienstag', 'Gruppe', 'Umsatz', 'Euro', 'Jahr', 'Umsatzsteigerung', 'Euro', 'Wachstum', 'Übernahmen', 'Mitarbeitern', 'Euro', 'Standort', 'Leuten', 'Euro', 'Übernahme', 'Marktstellung', 'Trodat', 'Geschäftsführer', 'Euro', 'Euro', 'Wachstum', 'Gruppe', 'Mitarbeiter', 'Prozent', 'Sitz', 'Holding', 'Produktionsstandort', 'Stempelerzeugung', 'Forschung', 'Entwicklung', 'Vertriebsstandort', 'Marchtrenk', 'Traditionsklub', 'FC', 'Bewerb', 'FC', 'Sonntag', 'Qualifikation', 'Saison', 'Eredivisie', 'Klub', 'Platz', 'Fünfter', 'Montag', 'Standort', 'Funkhaus', 'Frühstücksfernsehen', 'Wahl', 'Wahl', 'Tal', 'Regierungsparteien', 'Einheit',  ...

# %% [markdown]
# 7. Use the same architecture to train a language model on the nouns that were extracted
# from the German dataset in step 1 to 5. (Note: We do not need a „category“, you have
# to remove everything that belongs to „category“ from the code).

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
n_letters = len(all_letters) + 1 # Plus EOS marker
n_categories = 1
category_lines = {'NOUN': list_nouns_ascii}
all_categories = ['NOUN']

# %%
import torch
import torch.nn as nn

class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size

        self.i2h = nn.Linear(n_categories + input_size + hidden_size, hidden_size)
        self.i2o = nn.Linear(n_categories + input_size + hidden_size, output_size)
        self.o2o = nn.Linear(hidden_size + output_size, output_size)
        self.dropout = nn.Dropout(0.1)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, category, input, hidden):
        input_combined = torch.cat((category, input, hidden), 1)
        hidden = self.i2h(input_combined)
        output = self.i2o(input_combined)
        output_combined = torch.cat((hidden, output), 1)
        output = self.o2o(output_combined)
        output = self.dropout(output)
        output = self.softmax(output)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, self.hidden_size)

# %%
import random

# Random item from a list
def randomChoice(l):
    return l[random.randint(0, len(l) - 1)]

# Get a random category and random line from that category
def randomTrainingPair():
    category = randomChoice(all_categories)
    line = randomChoice(category_lines[category])
    return category, line

# %%
# One-hot vector for category
def categoryTensor(category):
    li = all_categories.index(category)
    tensor = torch.zeros(1, n_categories)
    tensor[0][li] = 1
    return tensor

# One-hot matrix of first to last letters (not including EOS) for input
def inputTensor(line):
    tensor = torch.zeros(len(line), 1, n_letters)
    for li in range(len(line)):
        letter = line[li]
        tensor[li][0][all_letters.find(letter)] = 1
    return tensor

# LongTensor of second letter to end (EOS) for target
def targetTensor(line):
    letter_indexes = [all_letters.find(line[li]) for li in range(1, len(line))]
    letter_indexes.append(n_letters - 1) # EOS
    return torch.LongTensor(letter_indexes)

# %%
# Make category, input, and target tensors from a random category, line pair
def randomTrainingExample():
    category, line = randomTrainingPair()
    category_tensor = categoryTensor(category)
    input_line_tensor = inputTensor(line)
    target_line_tensor = targetTensor(line)
    return category_tensor.to(device), input_line_tensor.to(device), target_line_tensor.to(device)

# %%
criterion = nn.NLLLoss()

learning_rate = 0.0005

def train(category_tensor, input_line_tensor, target_line_tensor):
    target_line_tensor.unsqueeze_(-1)
    hidden = rnn.initHidden()

    rnn.zero_grad()

    loss = 0

    for i in range(input_line_tensor.size(0)):
        output, hidden = rnn(category_tensor, input_line_tensor[i], hidden)
        l = criterion(output, target_line_tensor[i])
        loss += l

    loss.backward()

    for p in rnn.parameters():
        p.data.add_(p.grad.data, alpha=-learning_rate)

    return output, loss.item() / input_line_tensor.size(0)

# %%
import time
import math

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %%
rnn = RNN(n_letters, 128, n_letters)

n_iters = 100000
print_every = 5000
plot_every = 500
all_losses = []
total_loss = 0 # Reset every plot_every iters

start = time.time()

for iter in range(1, n_iters + 1):
    output, loss = train(*randomTrainingExample())
    total_loss += loss

    if iter % print_every == 0:
        print('%s (%d %d%%) %.4f' % (timeSince(start), iter, iter / n_iters * 100, loss))

    if iter % plot_every == 0:
        all_losses.append(total_loss / plot_every)
        total_loss = 0
# Out:
# 0m 35s (5000 5%) 2.8012
# 1m 10s (10000 10%) 2.2748
# 1m 45s (15000 15%) 2.1067
# 2m 20s (20000 20%) 2.5586
# 2m 55s (25000 25%) 1.9514
# 3m 30s (30000 30%) 2.4105
# 4m 6s (35000 35%) 2.4975
# 4m 41s (40000 40%) 2.3520
# 5m 16s (45000 45%) 2.2989
# 5m 52s (50000 50%) 3.0613
# 6m 27s (55000 55%) 2.2611
# 7m 3s (60000 60%) 1.4589
# 7m 39s (65000 65%) 2.7318
# 8m 14s (70000 70%) 3.1455
# 8m 50s (75000 75%) 2.0401
# 9m 25s (80000 80%) 1.7070
# 10m 0s (85000 85%) 1.9100
# 10m 35s (90000 90%) 2.8143
# 11m 11s (95000 95%) 1.9404
# 11m 46s (100000 100%) 1.4606

# %%
max_length = 20

# Sample from a category and starting letter
def sample(category, start_letter='A'):
    with torch.no_grad():  # no need to track history in sampling
        category_tensor = categoryTensor(category)
        input = inputTensor(start_letter)
        hidden = rnn.initHidden()

        output_name = start_letter


        for i in range(max_length):
            output, hidden = rnn(category_tensor, input[0], hidden)
            print(output)
            topv, topi = output.topk(1)
            topi = topi[0][0]
            if topi == n_letters - 1:
                break
            else:
                letter = all_letters[topi]
                output_name += letter
            input = inputTensor(letter)

        return output_name

# Get multiple samples from one category and multiple starting letters
def samples(category, start_letters='ABC'):
    for start_letter in start_letters:
        print(sample(category, start_letter))

samples('NOUN', 'HLCG')
# Out:
# tensor([[-1.1833, -5.0577, -5.6849, -4.6085, -1.5823, -6.1005, -6.7722, -4.9331,
#          -2.0833, -4.6085, -5.9606, -4.6085, -5.1133, -4.8482, -2.3428, -4.6085,
#          -7.3677, -3.7118, -5.5569, -5.0860, -2.5670, -6.2211, -5.9368, -6.3890,
#          -6.0249, -7.1959, -7.3955, -7.6593, -7.0031, -7.4208, -7.7561, -7.8081,
#          -7.4858, -7.6268, -7.3427, -7.5731, -7.5395, -7.7357, -7.6586, -7.6964,
#          -7.5832, -7.3339, -4.6085, -7.5895, -7.5998, -7.5157, -7.5985, -7.5407,
#          -7.8020, -7.7927, -7.9198, -7.6399, -7.7628, -7.9602, -7.7591, -3.7363,
#          -4.9092, -4.6085, -6.9435, -5.6857]])
# tensor([[-4.2264, -3.5514, -3.3296, -4.3992, -4.0550, -3.5948, -3.0245, -2.5457,
#          -4.5629, -6.9848, -5.1279, -2.0082, -4.0550, -1.9774, -6.6272, -4.5954,
#          -8.2156, -1.8623, -3.8806, -2.7594, -2.2747, -5.5141, -5.4886, -6.1770,
#          -5.9172, -5.4613, -8.1507, -8.7367, -8.0081, -8.1426, -8.5306, -8.6293,
#          -8.3736, -8.3427, -8.2082, -8.8051, -8.5212, -8.2258, -8.6466, -8.3814,
#          -8.2909, -8.0888, -4.0550, -4.0550, -8.4604, -8.7480, -8.5349, -8.5109,
#          -8.5670, -8.7894, -8.6804, -8.7527, -8.6502, -8.7813, -8.5353, -6.1863,
#          -6.4126, -5.3001, -5.0202, -5.8582]])
# tensor([[-3.2073, -3.8059, -3.8059, -2.5957, -2.7966, -3.5829, -3.7375, -3.8059,
#          -2.1716, -6.1845, -2.7268, -3.9338, -3.3200, -4.6419, -3.7910, -4.2260,
#          -3.8059, -4.5912, -2.7965, -2.1917, -3.7013, -5.2580, -4.3569, -7.1624,
#          -6.0089, -3.1677, -8.0422, -8.4272, -7.9664, -7.9121, -8.3728, -8.6460,
#          -8.3476, -8.3554, -3.8059, -8.7261, -8.3714, -8.4487, -8.5439, -8.2014,
#          -8.4597, -3.8059, -8.7078, -8.3073, -8.0425, -8.3308, -8.6273, -8.1881,
#          -8.4955, -8.6963, -8.9430, -3.8059, -8.7177, -8.4804, -8.5995, -5.3028,
#          -3.8059, -5.4223, -6.2738, -3.8059]])
# tensor([[-4.5878, -4.6351, -2.4640, -4.6348, -1.7417, -3.4436, -3.7088, -7.1076,
#          -6.4115, -6.9193, -3.6312, -3.9392, -4.4732, -2.7581, -2.7714, -4.8140,
#          -8.2583, -5.2637, -1.9452, -1.8948, -4.6901, -4.5479, -5.3596, -7.5372,
#          -3.9528, -3.1215, -3.9528, -8.7677, -8.2138, -8.2404, -8.7828, -8.8251,
#           -9.7816,  -4.7639,  -9.8991, -10.1461,  -9.5568,  -9.8681,  -7.9228,
#           -7.9760,  -7.4933,  -8.4367,  -0.2076]])
# Greiten

# %%
# Sample from a category and starting letter
def sample_highest_score(category, start_letters):
    with torch.no_grad():  # no need to track history in sampling
        category_tensor = categoryTensor(category)
        input = inputTensor(start_letters)
        hidden = rnn.initHidden()

        output_name = start_letters

        #Loop over the Input Letters except the last one and create input tensors for each
        for character in start_letters[:-1]:
          input = inputTensor(character)
          output, hidden = rnn(category_tensor, input[0], hidden)

        #create Input Tensor for last character 
        input = inputTensor(start_letters[-1])

        for i in range(max_length):
            output, hidden = rnn(category_tensor, input[0], hidden)
            topv, topi = output.topk(1)
            topi = topi[0][0]
            if topi == n_letters - 1:
                break
            else:
                letter = all_letters[topi]
                output_name += letter
            input = inputTensor(letter)

        return output_name

# %%
sample_highest_score('NOUN', 'Ni')
# Out:
# 'Nicher'

# %% [markdown]
# 9. Choose 10 random words from the training data and randomly cut-off a prefix. For
# every of those prefixes give an output for:
# > 1. The model extending the prefix with the max score approach.

# %%
# Random item from a list
def randomChoice(l):
    return l[random.randint(0, len(l) - 1)]

# %%
for i in range(10):
  word = randomChoice(list_nouns_ascii)
  print("Word: ", word)
  prefix = word[0:random.randint(1, len(word))]
  print("Prefix:", prefix)
  print(sample_highest_score('NOUN', word))
# Out:
# Word:  Mail
# Prefix: Mai
# Mailier
# Word:  Akademie
# Prefix: Akadem
# Akademien
# Word:  Geschäftsklima
# Prefix: Geschä
# Geschäftskliman
# Word:  Pavillons
# Prefix: P
# Pavillonstarien
# Word:  Plenarsitzungen
# Prefix: Plenarsitz
# Plenarsitzungen
# Word:  Flüchtlingen
# Prefix: Flüchtli
# Flüchtlingener
# Word:  Obfrau
# Prefix: O
# Obfraus
# Word:  Reifen
# Prefix: Reife
# Reifen
# Word:  Welthandel
# Prefix: Wel
# Welthandel
# Word:  Pirker
# Prefix: P
# Pirker

# %%
for i in range(10):
  word = randomChoice(list_nouns_ascii)
  print("Word: ", word)
  prefix = word[0:random.randint(1, len(word))]
  print("Prefix:", prefix)

  string = "".join((random.choices(all_letters, k=2)))
  prefix = prefix + string
  print("Prefix + random Character: ", prefix)
  print(sample_highest_score('NOUN', prefix))
# Out:
# Word:  Agency
# Prefix: Agency
# Prefix + random Character:  AgencymU
# AgencymUnt
# Word:  Wahlkampfveranstaltung
# Prefix: Wahlkampf
# Prefix + random Character:  WahlkampfÖS
# WahlkampfÖSter
# Word:  Prinzessin
# Prefix: Pri
# Prefix + random Character:  PriNs
# PriNser
# Word:  Studio
# Prefix: S
# Prefix + random Character:  Srg
# Srgeiter
# Word:  Leber
# Prefix: Leb
# Prefix + random Character:  LebÖw
# LebÖwerter
# Word:  Tat
# Prefix: Tat
# Prefix + random Character:  TatÜw
# TatÜwerten
# Word:  Förderländern
# Prefix: Förder
# Prefix + random Character:  Förderse
# Förderser
# Word:  Datum
# Prefix: D
# Prefix + random Character:  Djm
# Djman
# Word:  Konsum
# Prefix: K
# Prefix + random Character:  KyA
# KyAnt
# Word:  Kandidat
# Prefix: Ka
# Prefix + random Character:  KaDC
# KaDCer
